# %%
      "semanticAttributes": {
        "query": "생수",
        "productListID": "SearchAPI",
        "products": [
          {
            "quantity": null,
            "productID": null,
            "price": 5990,
            "name": "탐사 샘물",
            "currency": null,
            "position": 0
          },
          {
            "quantity": null,
            "productID": null,
            "price": 10700,
            "name": "백산수 무라벨 생수",
            "currency": null,
            "position": 1
          },
          {
            "quantity": null,
            "productID": null,
            "price": 7840,
            "name": "풀무원샘물 무라벨 생수",
            "currency": null,
            "position": 2
          },
          {
            "quantity": null,
            "productID": null,
            "price": 14930,
            "name": "백산수 무라벨 생수",
            "currency": null,
            "position": 3
          },
          {
            "quantity": null,
            "productID": null,
            "price": 14900,
            "name": "백산수 무라벨 생수",
            "currency": null,
            "position": 4
          },
          {
            "quantity": null,
            "productID": null,
            "price": 10050,
            "name": "스파클 생수 무라벨",
            "currency": null,
            "position": 5
          },
          {
            "quantity": null,
            "productID": null,
            "price": 13200,
            "name": "몽베스트 위드어스 무라벨 생수",
            "currency": null,
            "position": 6
          },
          {
            "quantity": null,
            "productID": null,
            "price": 8640,
            "name": "아이시스 8.0",
            "currency": null,
            "position": 7
          },
          {
            "quantity": null,
            "productID": null,
            "price": 4890,
            "name": "제주 탐사수",
            "currency": null,
            "position": 8
          },
          {
            "quantity": null,
            "productID": null,
            "price": 17200,
            "name": "몽베스트 위드어스 무라벨 생수",
            "currency": null,
            "position": 9
          }
        ]
      },
